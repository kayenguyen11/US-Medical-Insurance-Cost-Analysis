# %% [markdown]
# # U.S. Medical Insurance Costs
#
# *In this project, I will be investigating a medical insurance costs dataset in a .csv file using the Python skills that I have developed.*
# ***
# *Step 1: Import all needed libraries, classes and the .csv file*
# ***
# ***
# *Step 2: Analysis the dataset by:*
# ***
# *- Find out the average/median/min/max age of the patients in the dataset, then visualize the age distribution.*
# ***
# *- Analyze where a majority of the individuals are from.*
# ***
# *- Number of smokers and non-smokers, number of male and female smokers.*
# ***
# *- Look at the different costs between smokers vs. non-smokers, between males and females.*
# ***
# *- Figure out the number of children the patients have*

# %%
#Step 1: Import libraries and data
# %run MedicalInsurance.py
from MedicalInsurance import MedicalInsurance

if __name__ == '__main__':
    filepath = 'insurance.csv'
    insurance_data = MedicalInsurance(filepath)
    #load data
    insurance_data.import_data()

# %%
#Step 2.1: Age analysis
insurance_data.age_chart()
# Out:
# Average age of patents is 39.20702541106129.
# Median age of patents is 39.0.
# The oldest patient is 64 years old
# The youngest patent is 18 years old.

# %% [markdown]
# # Conclusion 1:
# Patients' ages are in the range from 18 years old to 64 years old, average age is 39 years old.
# As the mean and median of age are almost the same, which means the age data has symmetrical distribution.
# Among 1338 patients, there are more than 160 patients (11%) are in the ages of 18-20.

# %%
#Step 2.2 Region analysis:
insurance_data.regions_chart()
# Out:
# There are southwest people from 325
# There are southeast people from 364
# There are northwest people from 325
# There are northeast people from 324

# %% [markdown]
# # Conclusion 2:
# Patients are from 4 regions of the US. It can be seen that number of patients from Northwest, Southwest and Northeast are amlost equal(325, 325, 324 patients), while the Southeast has a slightly higher number of patients: 364.

# %%
#3.3 Smoker status
## count smokers vs non-smokers + gender
insurance_data.smoker_and_sex_count()
# Out:
# Among the patients, 20.48% of them are smokers, and 79.52% of them are non-smokers
# The are  159  of smokers are male
# The are  115  of smokers are female

# %%
#3.4 checking association between smokers vs gender, smokers vs charges
insurance_data.association_chart()

# %% [markdown]
# From the boxplots above, it seems that there is an strong association between smoking status and the insurance charges, while there is unlikely any assocation between gender and charges.

# %%
##insurance costs for smokers and no-smokers
insurance_data.draw_smoker_average_cost_chart()
# Out:
# Average costs of patients is 13270.422265141257 US dollars.
# Average costs for smokers is 32050.23 US dollars.
# Average costs for non-smokers is 8434.27 US dollars.

# %% [markdown]
# # Conclusion 3:
# Average insurance costs for each patient is 13270.42 US dollars.
# It seems that there is no association between gender and the insurance cost. However, the second box plot show that there is differences between the costs for smokers and non-smokers. The average insurances costs for smokers is much higher than the non-smokers (4 times).

# %%
#3.5 Children number analysis
insurance_data.count_children()
# Out:
# There are 574 patients having 0 chilren.
# There are 324 patients having 1 chilren.
# There are 157 patients having 3 chilren.
# There are 240 patients having 2 chilren.
# There are 18 patients having 5 chilren.
# There are 25 patients having 4 chilren.

# %% [markdown]
# # Conclusion 5:
# The number of chidlren that the patients have varies, ranging from 0 to 5 children in which those having no children dominate (574 patients).
# Half of the patient have 1-3 patients, while there are only 43 patients having 4-5 children.

# %% [markdown]
# # END!
